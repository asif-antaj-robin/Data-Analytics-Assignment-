# %% [markdown]
# # Getting Started with Data Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv("employee_data.csv")
df
# Out:
#      EmployeeID             Name  Age  Gender   Department    JobTitle  \
# 0          1000  George Williams   50    Male           HR  Consultant
# 1          1001       Jane Brown   36  Female        Sales   Executive
# 2          1002   George Johnson   29  Female      Support     Manager
# 3          1003  Hannah Williams   42   Other  Engineering     Manager
# 4          1004     George Davis   40   Other           IT   Developer
# ..          ...              ...  ...     ...          ...         ...
# 545        1545        Bob Jones   39    Male  Engineering  Technician
# 546        1546    Jane Williams   35   Other    Logistics   Developer
# 547        1547     Diana Wilson   36  Female  Engineering     Analyst
# 548        1548    Hannah Taylor   52    Male           IT   Developer
# 549        1549     Fiona Miller   22    Male        Sales  Consultant
#
#      Salary DateOfJoining MaritalStatus    Education  ...  \
# 0     65057     10/8/2017        Single       Master  ...
# 1     31239      3/7/2021        Single          PhD  ...
# 2     95661     9/27/2016        Single  High School  ...
# 3     75272    11/18/2018        Single          PhD  ...
# 4    119393     3/14/2019       Married       Master  ...
# ..      ...           ...           ...          ...  ...
# 545   68714      7/3/2014        Single     Bachelor  ...
# 546   84093      9/1/2017      Divorced          PhD  ...
# 547   85419      8/3/2023      Divorced       Master  ...
# 548   79145     5/22/2010       Married       Master  ...
# 549  107425    12/26/2013       Married     Bachelor  ...
#
#                              Email  PhoneNumber        City EmploymentType  \
# 0    george.williams@corporate.org   1762717327       Dhaka       Contract
# 1         jane.brown@corporate.org   1566784995      Sylhet      Part-time
# 2     george.johnson@corporate.org   1348371389    Rajshahi      Full-time
# 3    hannah.williams@corporate.org   1564436727     Barisal      Full-time
# 4         george.davis@example.com   1130130576       Dhaka      Part-time
# ..                             ...          ...         ...            ...
# 545          bob.jones@example.com   1508844502    Rajshahi      Full-time
# 546    jane.williams@corporate.org   1947982501      Khulna      Part-time
# 547       diana.wilson@example.com   1361782146      Sylhet       Contract
# 548      hannah.taylor@company.com   1318980404  Chittagong       Contract
# 549       fiona.miller@example.com   1781051213      Sylhet      Full-time
#
#     IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled  \
# 0         No        16:21.8                   18               1
# 1         No        54:32.7                   10               5
# 2        Yes        54:32.7                   17               9
# 3         No        16:21.8                    3               3
# 4        Yes        27:16.4                   15               4
# ..       ...            ...                  ...             ...
# 545      Yes        54:32.7                   11               1
# 546      Yes        38:10.9                   25               4
# 547      Yes        32:43.6                   26               0
# 548      Yes        10:54.5                   16               8
# 549       No        00:00.0                    0               3
#
#     Certifications PromotionEligible
# 0              AWS               Yes
# 1     Scrum Master               Yes
# 2              AWS               Yes
# 3     Data Analyst               Yes
# 4     Scrum Master                No
# ..             ...               ...
# 545            AWS                No
# 546            PMP               Yes
# 547           CCNA                No
# 548            AWS               Yes
# 549            AWS               Yes
#
# [550 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   EmployeeID           550 non-null    int64
#  1   Name                 550 non-null    object
#  2   Age                  550 non-null    int64
#  3   Gender               550 non-null    object
#  4   Department           550 non-null    object
#  5   JobTitle             550 non-null    object
#  6   Salary               550 non-null    int64
#  7   DateOfJoining        550 non-null    object
#  8   MaritalStatus        550 non-null    object
#  9   Education            550 non-null    object
#  10  OverTime             550 non-null    object
#  11  MonthlyIncome        550 non-null    int64
#  12  Hobbies              550 non-null    object
#  13  ProgrammingSkills    410 non-null    object
#  14  Religion             550 non-null    object
#  15  Email                550 non-null    object
#  16  PhoneNumber          550 non-null    int64
#  17  City                 550 non-null    object
#  18  EmploymentType       550 non-null    object
#  19  IsRemote             550 non-null    object
#  20  LastWorkingDay       505 non-null    object
#  21  LeavesTakenLastYear  550 non-null    int64
#  22  ProjectsHandled      550 non-null    int64
#  23  Certifications       457 non-null    object
#  24  PromotionEligible    550 non-null    object
# dtypes: int64(7), object(18)
# memory usage: 107.6+ KB

# %%
df.shape
# Out:
# (550, 25)

# %%
df.size
# Out:
# 13750

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Age', 'Gender', 'Department', 'JobTitle',
#        'Salary', 'DateOfJoining', 'MaritalStatus', 'Education', 'OverTime',
#        'MonthlyIncome', 'Hobbies', 'ProgrammingSkills', 'Religion', 'Email',
#        'PhoneNumber', 'City', 'EmploymentType', 'IsRemote', 'LastWorkingDay',
#        'LeavesTakenLastYear', 'ProjectsHandled', 'Certifications',
#        'PromotionEligible'],
#       dtype='object')

# %%
pd.set_option("display.max_columns", 20)
df
# Out:
#      EmployeeID             Name  Age  Gender   Department    JobTitle  \
# 0          1000  George Williams   50    Male           HR  Consultant
# 1          1001       Jane Brown   36  Female        Sales   Executive
# 2          1002   George Johnson   29  Female      Support     Manager
# 3          1003  Hannah Williams   42   Other  Engineering     Manager
# 4          1004     George Davis   40   Other           IT   Developer
# ..          ...              ...  ...     ...          ...         ...
# 545        1545        Bob Jones   39    Male  Engineering  Technician
# 546        1546    Jane Williams   35   Other    Logistics   Developer
# 547        1547     Diana Wilson   36  Female  Engineering     Analyst
# 548        1548    Hannah Taylor   52    Male           IT   Developer
# 549        1549     Fiona Miller   22    Male        Sales  Consultant
#
#      Salary DateOfJoining MaritalStatus    Education  ...  \
# 0     65057     10/8/2017        Single       Master  ...
# 1     31239      3/7/2021        Single          PhD  ...
# 2     95661     9/27/2016        Single  High School  ...
# 3     75272    11/18/2018        Single          PhD  ...
# 4    119393     3/14/2019       Married       Master  ...
# ..      ...           ...           ...          ...  ...
# 545   68714      7/3/2014        Single     Bachelor  ...
# 546   84093      9/1/2017      Divorced          PhD  ...
# 547   85419      8/3/2023      Divorced       Master  ...
# 548   79145     5/22/2010       Married       Master  ...
# 549  107425    12/26/2013       Married     Bachelor  ...
#
#                              Email  PhoneNumber        City EmploymentType  \
# 0    george.williams@corporate.org   1762717327       Dhaka       Contract
# 1         jane.brown@corporate.org   1566784995      Sylhet      Part-time
# 2     george.johnson@corporate.org   1348371389    Rajshahi      Full-time
# 3    hannah.williams@corporate.org   1564436727     Barisal      Full-time
# 4         george.davis@example.com   1130130576       Dhaka      Part-time
# ..                             ...          ...         ...            ...
# 545          bob.jones@example.com   1508844502    Rajshahi      Full-time
# 546    jane.williams@corporate.org   1947982501      Khulna      Part-time
# 547       diana.wilson@example.com   1361782146      Sylhet       Contract
# 548      hannah.taylor@company.com   1318980404  Chittagong       Contract
# 549       fiona.miller@example.com   1781051213      Sylhet      Full-time
#
#     IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled  \
# 0         No        16:21.8                   18               1
# 1         No        54:32.7                   10               5
# 2        Yes        54:32.7                   17               9
# 3         No        16:21.8                    3               3
# 4        Yes        27:16.4                   15               4
# ..       ...            ...                  ...             ...
# 545      Yes        54:32.7                   11               1
# 546      Yes        38:10.9                   25               4
# 547      Yes        32:43.6                   26               0
# 548      Yes        10:54.5                   16               8
# 549       No        00:00.0                    0               3
#
#     Certifications PromotionEligible
# 0              AWS               Yes
# 1     Scrum Master               Yes
# 2              AWS               Yes
# 3     Data Analyst               Yes
# 4     Scrum Master                No
# ..             ...               ...
# 545            AWS                No
# 546            PMP               Yes
# 547           CCNA                No
# 548            AWS               Yes
# 549            AWS               Yes
#
# [550 rows x 25 columns]

# %%
df.head()
# Out:
#    EmployeeID             Name  Age  Gender   Department    JobTitle  Salary  \
# 0        1000  George Williams   50    Male           HR  Consultant   65057
# 1        1001       Jane Brown   36  Female        Sales   Executive   31239
# 2        1002   George Johnson   29  Female      Support     Manager   95661
# 3        1003  Hannah Williams   42   Other  Engineering     Manager   75272
# 4        1004     George Davis   40   Other           IT   Developer  119393
#
#   DateOfJoining MaritalStatus    Education  ...  \
# 0     10/8/2017        Single       Master  ...
# 1      3/7/2021        Single          PhD  ...
# 2     9/27/2016        Single  High School  ...
# 3    11/18/2018        Single          PhD  ...
# 4     3/14/2019       Married       Master  ...
#
#                            Email  PhoneNumber      City EmploymentType  \
# 0  george.williams@corporate.org   1762717327     Dhaka       Contract
# 1       jane.brown@corporate.org   1566784995    Sylhet      Part-time
# 2   george.johnson@corporate.org   1348371389  Rajshahi      Full-time
# 3  hannah.williams@corporate.org   1564436727   Barisal      Full-time
# 4       george.davis@example.com   1130130576     Dhaka      Part-time
#
#   IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled Certifications  \
# 0       No        16:21.8                   18               1            AWS
# 1       No        54:32.7                   10               5   Scrum Master
# 2      Yes        54:32.7                   17               9            AWS
# 3       No        16:21.8                    3               3   Data Analyst
# 4      Yes        27:16.4                   15               4   Scrum Master
#
#   PromotionEligible
# 0               Yes
# 1               Yes
# 2               Yes
# 3               Yes
# 4                No
#
# [5 rows x 25 columns]

# %%
df.head(10)
# Out:
#    EmployeeID             Name  Age  Gender   Department    JobTitle  Salary  \
# 0        1000  George Williams   50    Male           HR  Consultant   65057
# 1        1001       Jane Brown   36  Female        Sales   Executive   31239
# 2        1002   George Johnson   29  Female      Support     Manager   95661
# 3        1003  Hannah Williams   42   Other  Engineering     Manager   75272
# 4        1004     George Davis   40   Other           IT   Developer  119393
# 5        1005     Diana Garcia   44    Male      Finance  Technician   91212
# 6        1006   Charlie Wilson   32   Other    Marketing  Consultant   45398
# 7        1007    Jane Williams   32  Female      Finance     Analyst   86503
# 8        1008    Jane Williams   45  Female        Sales    Engineer   36638
# 9        1009     Fiona Garcia   57    Male           HR     Manager   36570
#
#   DateOfJoining MaritalStatus    Education  ...  \
# 0     10/8/2017        Single       Master  ...
# 1      3/7/2021        Single          PhD  ...
# 2     9/27/2016        Single  High School  ...
# 3    11/18/2018        Single          PhD  ...
# 4     3/14/2019       Married       Master  ...
# 5    11/17/2011        Single  High School  ...
# 6     12/1/2015       Married  High School  ...
# 7     12/2/2020        Single     Bachelor  ...
# 8     2/18/2021       Married  High School  ...
# 9     4/17/2014      Divorced  High School  ...
#
#                            Email  PhoneNumber      City EmploymentType  \
# 0  george.williams@corporate.org   1762717327     Dhaka       Contract
# 1       jane.brown@corporate.org   1566784995    Sylhet      Part-time
# 2   george.johnson@corporate.org   1348371389  Rajshahi      Full-time
# 3  hannah.williams@corporate.org   1564436727   Barisal      Full-time
# 4       george.davis@example.com   1130130576     Dhaka      Part-time
# 5     diana.garcia@corporate.org   1851756626  Rajshahi       Contract
# 6     charlie.wilson@company.com   1300391188  Rajshahi      Part-time
# 7      jane.williams@example.com   1208669409  Rajshahi         Intern
# 8    jane.williams@corporate.org   1640415458  Rajshahi         Intern
# 9       fiona.garcia@example.com   1247945600   Barisal      Full-time
#
#   IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled Certifications  \
# 0       No        16:21.8                   18               1            AWS
# 1       No        54:32.7                   10               5   Scrum Master
# 2      Yes        54:32.7                   17               9            AWS
# 3       No        16:21.8                    3               3   Data Analyst
# 4      Yes        27:16.4                   15               4   Scrum Master
# 5       No        27:16.4                   24               0            PMP
# 6       No        16:21.8                   14               4            NaN
# 7      Yes        21:49.1                    4               5            AWS
# 8      Yes        16:21.8                   19               8   Data Analyst
# 9      Yes        54:32.7                    4               6   Scrum Master
#
#   PromotionEligible
# 0               Yes
# 1               Yes
# 2               Yes
# 3               Yes
# 4                No
# 5                No
# 6               Yes
# 7               Yes
# 8               Yes
# 9                No
#
# [10 rows x 25 columns]

# %%
df.tail()
# Out:
#      EmployeeID           Name  Age  Gender   Department    JobTitle  Salary  \
# 545        1545      Bob Jones   39    Male  Engineering  Technician   68714
# 546        1546  Jane Williams   35   Other    Logistics   Developer   84093
# 547        1547   Diana Wilson   36  Female  Engineering     Analyst   85419
# 548        1548  Hannah Taylor   52    Male           IT   Developer   79145
# 549        1549   Fiona Miller   22    Male        Sales  Consultant  107425
#
#     DateOfJoining MaritalStatus Education  ...                        Email  \
# 545      7/3/2014        Single  Bachelor  ...        bob.jones@example.com
# 546      9/1/2017      Divorced       PhD  ...  jane.williams@corporate.org
# 547      8/3/2023      Divorced    Master  ...     diana.wilson@example.com
# 548     5/22/2010       Married    Master  ...    hannah.taylor@company.com
# 549    12/26/2013       Married  Bachelor  ...     fiona.miller@example.com
#
#      PhoneNumber        City EmploymentType IsRemote LastWorkingDay  \
# 545   1508844502    Rajshahi      Full-time      Yes        54:32.7
# 546   1947982501      Khulna      Part-time      Yes        38:10.9
# 547   1361782146      Sylhet       Contract      Yes        32:43.6
# 548   1318980404  Chittagong       Contract      Yes        10:54.5
# 549   1781051213      Sylhet      Full-time       No        00:00.0
#
#      LeavesTakenLastYear ProjectsHandled Certifications PromotionEligible
# 545                   11               1            AWS                No
# 546                   25               4            PMP               Yes
# 547                   26               0           CCNA                No
# 548                   16               8            AWS               Yes
# 549                    0               3            AWS               Yes
#
# [5 rows x 25 columns]

# %%
df.tail(10)
# Out:
#      EmployeeID            Name  Age  Gender   Department    JobTitle  Salary  \
# 540        1540       Bob Jones   58   Other      Finance    Engineer  119489
# 541        1541  Ethan Williams   57   Other      Finance  Consultant   56806
# 542        1542     John Taylor   56   Other           IT     Manager   75000
# 543        1543    Jane Johnson   40   Other           HR     Manager   52168
# 544        1544  Hannah Johnson   41  Female    Logistics    Engineer  100119
# 545        1545       Bob Jones   39    Male  Engineering  Technician   68714
# 546        1546   Jane Williams   35   Other    Logistics   Developer   84093
# 547        1547    Diana Wilson   36  Female  Engineering     Analyst   85419
# 548        1548   Hannah Taylor   52    Male           IT   Developer   79145
# 549        1549    Fiona Miller   22    Male        Sales  Consultant  107425
#
#     DateOfJoining MaritalStatus    Education  ...  \
# 540    12/27/2021       Married          PhD  ...
# 541     6/14/2019        Single       Master  ...
# 542     3/16/2022        Single       Master  ...
# 543      6/3/2022       Married     Bachelor  ...
# 544    11/11/2015      Divorced  High School  ...
# 545      7/3/2014        Single     Bachelor  ...
# 546      9/1/2017      Divorced          PhD  ...
# 547      8/3/2023      Divorced       Master  ...
# 548     5/22/2010       Married       Master  ...
# 549    12/26/2013       Married     Bachelor  ...
#
#                             Email  PhoneNumber        City EmploymentType  \
# 540         bob.jones@company.com   1100466474       Dhaka      Part-time
# 541  ethan.williams@corporate.org   1250342793      Khulna      Full-time
# 542     john.taylor@corporate.org   1229702500      Sylhet       Contract
# 543    jane.johnson@corporate.org   1344374975     Barisal      Part-time
# 544    hannah.johnson@example.com   1898700140      Sylhet         Intern
# 545         bob.jones@example.com   1508844502    Rajshahi      Full-time
# 546   jane.williams@corporate.org   1947982501      Khulna      Part-time
# 547      diana.wilson@example.com   1361782146      Sylhet       Contract
# 548     hannah.taylor@company.com   1318980404  Chittagong       Contract
# 549      fiona.miller@example.com   1781051213      Sylhet      Full-time
#
#     IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled  \
# 540       No        21:49.1                   11               5
# 541      Yes        16:21.8                    7               6
# 542      Yes        10:54.5                   28               3
# 543      Yes        05:27.3                    1               5
# 544       No        49:05.5                    2               4
# 545      Yes        54:32.7                   11               1
# 546      Yes        38:10.9                   25               4
# 547      Yes        32:43.6                   26               0
# 548      Yes        10:54.5                   16               8
# 549       No        00:00.0                    0               3
#
#     Certifications PromotionEligible
# 540            PMP                No
# 541   Scrum Master                No
# 542   Scrum Master               Yes
# 543            NaN                No
# 544   Data Analyst               Yes
# 545            AWS                No
# 546            PMP               Yes
# 547           CCNA                No
# 548            AWS               Yes
# 549            AWS               Yes
#
# [10 rows x 25 columns]

# %% [raw]
# Asif Antaj Robin
# Cumilla Polytechnic Institute (CPI)
# Computer Science and Technology (CST)
# Phone Number : 01312531960
