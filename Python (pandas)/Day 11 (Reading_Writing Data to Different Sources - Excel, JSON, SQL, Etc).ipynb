# %% [markdown]
# # Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc

# %%
import pandas as pd

# %%
df = pd.read_csv("employee_data_update.csv", index_col= "EmployeeID")  #index_col= 0
df.head()
# Out:
#                        Name  Age  Gender   Department    JobTitle  Salary  \
# EmployeeID
# 1000        George Williams   50    Male           HR  Consultant   65057
# 1001             Jane Brown   36  Female        Sales   Executive   31239
# 1002         George Johnson   29  Female      Support     Manager   95661
# 1003        Hannah Williams   42   Other  Engineering     Manager   75272
# 1004           George Davis   40   Other           IT   Developer  119393
#
#            DateOfJoining MaritalStatus    Education OverTime  ...      City  \
# EmployeeID                                                    ...
# 1000           10/8/2017        Single       Master      Yes  ...     Dhaka
# 1001            3/7/2021        Single          PhD       No  ...    Sylhet
# 1002           9/27/2016        Single  High School      Yes  ...  Rajshahi
# 1003          11/18/2018        Single          PhD       No  ...   Barisal
# ...

# %%
pd.set_option("display.max_columns", 25)
pd.set_option("display.max_rows", 500)

# %%
filt = (df['Country'] == "Bangladesh")
bd_df = df.loc[filt]
bd_df.head()
# Out:
#                      Name  Age  Gender Department    JobTitle  Salary  \
# EmployeeID
# 1011         Jane Johnson   24  Female         HR    Engineer   39110
# 1019          Fiona Smith   54    Male    Support     Analyst   73753
# 1038           Jane Brown   23  Female      Sales   Developer   67208
# 1039        Fiona Johnson   41   Other      Sales  Consultant   84061
# 1048           John Brown   23    Male    Support    Engineer   38125
#
#            DateOfJoining MaritalStatus    Education OverTime  MonthlyIncome  \
# EmployeeID
# 1011          12/19/2016       Married       Master       No           7752
# 1019           10/9/2011       Married          PhD       No           7214
# 1038            4/6/2011      Divorced          PhD      Yes           8958
# 1039           5/14/2016        Single  High School      Yes           5256
# 1048           8/29/2015        Single       Master       No           5703
#
# ...

# %%
bd_df.to_csv('bd_employee_data.csv')

# %%
#bd_df.to_csv("bd_employee_data.csv", sep = '\t')

# %%
test = pd.read_csv("bd_employee_data.csv", index_col= 0)
test
# Out:
#                        Name  Age  Gender   Department    JobTitle  Salary  \
# EmployeeID
# 1011           Jane Johnson   24  Female           HR    Engineer   39110
# 1019            Fiona Smith   54    Male      Support     Analyst   73753
# 1038             Jane Brown   23  Female        Sales   Developer   67208
# 1039          Fiona Johnson   41   Other        Sales  Consultant   84061
# 1048             John Brown   23    Male      Support    Engineer   38125
# 1049            Ethan Davis   27   Other      Finance     Analyst   66059
# 1051           Ethan Garcia   50  Female           IT  Consultant   47087
# 1060         Charlie Miller   29  Female           HR     Manager   69882
# 1062           Hannah Davis   44   Other        Sales    Engineer   59165
# 1064           George Brown   37    Male      Support     Manager   34114
# 1069           Bob Williams   50    Male  Engineering    Engineer   47772
# ...

# %%
bd_df.to_json('bd employee data test json', orient='records', lines = True)

# %%
test = pd.read_json('bd employee data test json', orient='records', lines = True)
test
# Out:
#                Name  Age  Gender   Department    JobTitle  Salary  \
# 0      Jane Johnson   24  Female           HR    Engineer   39110
# 1       Fiona Smith   54    Male      Support     Analyst   73753
# 2        Jane Brown   23  Female        Sales   Developer   67208
# 3     Fiona Johnson   41   Other        Sales  Consultant   84061
# 4        John Brown   23    Male      Support    Engineer   38125
# 5       Ethan Davis   27   Other      Finance     Analyst   66059
# 6      Ethan Garcia   50  Female           IT  Consultant   47087
# 7    Charlie Miller   29  Female           HR     Manager   69882
# 8      Hannah Davis   44   Other        Sales    Engineer   59165
# 9      George Brown   37    Male      Support     Manager   34114
# 10     Bob Williams   50    Male  Engineering    Engineer   47772
# 11      John Taylor   32  Female      Support   Executive   61324
# 12      Ethan Davis   22  Female      Support     Manager   41556
# ...

# %%
test.head()
# Out:
#             Name  Age  Gender Department    JobTitle  Salary DateOfJoining  \
# 0   Jane Johnson   24  Female         HR    Engineer   39110    12/19/2016
# 1    Fiona Smith   54    Male    Support     Analyst   73753     10/9/2011
# 2     Jane Brown   23  Female      Sales   Developer   67208      4/6/2011
# 3  Fiona Johnson   41   Other      Sales  Consultant   84061     5/14/2016
# 4     John Brown   23    Male    Support    Engineer   38125     8/29/2015
#
#   MaritalStatus    Education OverTime  MonthlyIncome  \
# 0       Married       Master       No           7752
# 1       Married          PhD       No           7214
# 2      Divorced          PhD      Yes           8958
# 3        Single  High School      Yes           5256
# 4        Single       Master       No           5703
#
#                          Hobbies  ...                       Email PhoneNumber  \
# 0  Reading, Cooking, Photography  ...  jane.johnson@corporate.org  1269846195
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('mysql+pymysql://root:130602@localhost:3306/sample_db')
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/sample_db)

# %%
bd_df.to_sql("sample_db", engine)
# Out:
# 64

# %%
bd_df.to_sql("sample_table", engine)
# Out:
# 64

# %%
bd_df.to_sql("sample_table", engine, if_exists='replace')
# Out:
# 64

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='EmployeeID')
sql_df.head()
# Out:
#                      Name  Age  Gender Department    JobTitle  Salary  \
# EmployeeID
# 1011         Jane Johnson   24  Female         HR    Engineer   39110
# 1019          Fiona Smith   54    Male    Support     Analyst   73753
# 1038           Jane Brown   23  Female      Sales   Developer   67208
# 1039        Fiona Johnson   41   Other      Sales  Consultant   84061
# 1048           John Brown   23    Male    Support    Engineer   38125
#
#            DateOfJoining MaritalStatus    Education OverTime  MonthlyIncome  \
# EmployeeID
# 1011          12/19/2016       Married       Master       No           7752
# 1019           10/9/2011       Married          PhD       No           7214
# 1038            4/6/2011      Divorced          PhD      Yes           8958
# 1039           5/14/2016        Single  High School      Yes           5256
# 1048           8/29/2015        Single       Master       No           5703
#
# ...

# %%
sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col='EmployeeID')
sql_df.head()
# Out:
#                      Name  Age  Gender Department    JobTitle  Salary  \
# EmployeeID
# 1011         Jane Johnson   24  Female         HR    Engineer   39110
# 1019          Fiona Smith   54    Male    Support     Analyst   73753
# 1038           Jane Brown   23  Female      Sales   Developer   67208
# 1039        Fiona Johnson   41   Other      Sales  Consultant   84061
# 1048           John Brown   23    Male    Support    Engineer   38125
#
#            DateOfJoining MaritalStatus    Education OverTime  MonthlyIncome  \
# EmployeeID
# 1011          12/19/2016       Married       Master       No           7752
# 1019           10/9/2011       Married          PhD       No           7214
# 1038            4/6/2011      Divorced          PhD      Yes           8958
# 1039           5/14/2016        Single  High School      Yes           5256
# 1048           8/29/2015        Single       Master       No           5703
#
# ...

# %% [raw]
# Asif Antaj Robin
# Cumilla Polytechnic Institute (CPI)
# Computer Science and Technology (CST)
# Phone Number : 01312531960
