# %% [markdown]
# # Updating Rows and Columns - Modifying Data Within DataFrames

# %%
import pandas as pd

# %%
People = {
    "First Name" : ["Asif Antaj", "Afrin Jahan", "Afifa Jahan", "Asif Antaj"],
    "Last Name" : ["Robin", "Rupa", "Rafa", "Rayhan"],
    "Email" : ["AsifAntajRobin@Gmal.Com", "Afrin@Cmail.Com", "Afifa@Gmail.Com", "Asif@Gmail.Com"]
}

# %%
df = pd.DataFrame(People)
df
# Out:
#     First Name Last Name                    Email
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com

# %%
df.columns
# Out:
# Index(['First Name', 'Last Name', 'Email'], dtype='object')

# %%
df.columns = ["First_Name", "Last_Name", "User_Email"]
df
# Out:
#     First_Name Last_Name               User_Email
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#     FIRST_NAME LAST_NAME               USER_EMAIL
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com

# %%
df.columns = df.columns.str.replace("_", " ")
df
# Out:
#     FIRST NAME LAST NAME               USER EMAIL
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com

# %%
df.rename(columns = {"FIRST NAME":"First_Name", "LAST NAME":"Last_Name", "USER EMAIL":"Email"}, inplace = True)
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com

# %%
df.loc[3]
# Out:
# First_Name        Asif Antaj
# Last_Name             Rayhan
# Email         Asif@Gmail.Com
# Name: 3, dtype: object

# %%
#add row
df.loc[4] = ["Md Arif", "Uddin", "arif@gmail.com"]
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com
# 4      Md Arif     Uddin           arif@gmail.com

# %%
#update row
df.loc[4, ["First_Name", "Email"]] = ["Md Azim", "Azim@Gmail.Com"]
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com
# 4      Md Azim     Uddin           Azim@Gmail.Com

# %%
filt = (df['Email'] == 'azim@gmail.com')
df[filt]["Last_Name"] = "Khan"
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com
# 4      Md Azim     Uddin           Azim@Gmail.Com

# %%
df.loc[filt, "Last_Name"] = "Khan"
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  AsifAntajRobin@Gmal.Com
# 1  Afrin Jahan      Rupa          Afrin@Cmail.Com
# 2  Afifa Jahan      Rafa          Afifa@Gmail.Com
# 3   Asif Antaj    Rayhan           Asif@Gmail.Com
# 4      Md Azim     Uddin           Azim@Gmail.Com

# %%
df["Email"].str.lower()
# Out:
# 0    asifantajrobin@gmal.com
# 1            afrin@cmail.com
# 2            afifa@gmail.com
# 3             asif@gmail.com
# 4             azim@gmail.com
# Name: Email, dtype: object

# %%
df["Email"] = df["Email"].str.lower()
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  asifantajrobin@gmal.com
# 1  Afrin Jahan      Rupa          afrin@cmail.com
# 2  Afifa Jahan      Rafa          afifa@gmail.com
# 3   Asif Antaj    Rayhan           asif@gmail.com
# 4      Md Azim     Uddin           azim@gmail.com

# %% [raw]
# 1. apply
# 2. map
# 3. applymap
# 4. replace

# %%
df["Email"].apply(len)
# Out:
# 0    23
# 1    15
# 2    15
# 3    14
# 4    14
# Name: Email, dtype: int64

# %%
def update_email(Email):
    return Email.upper()

# %%
df["Email"].apply(update_email)
# Out:
# 0    ASIFANTAJROBIN@GMAL.COM
# 1            AFRIN@CMAIL.COM
# 2            AFIFA@GMAIL.COM
# 3             ASIF@GMAIL.COM
# 4             AZIM@GMAIL.COM
# Name: Email, dtype: object

# %%
df["Email"] = df["Email"].apply(update_email)
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  ASIFANTAJROBIN@GMAL.COM
# 1  Afrin Jahan      Rupa          AFRIN@CMAIL.COM
# 2  Afifa Jahan      Rafa          AFIFA@GMAIL.COM
# 3   Asif Antaj    Rayhan           ASIF@GMAIL.COM
# 4      Md Azim     Uddin           AZIM@GMAIL.COM

# %%
df["Email"] = df["Email"].apply(lambda x: x.lower())
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  asifantajrobin@gmal.com
# 1  Afrin Jahan      Rupa          afrin@cmail.com
# 2  Afifa Jahan      Rafa          afifa@gmail.com
# 3   Asif Antaj    Rayhan           asif@gmail.com
# 4      Md Azim     Uddin           azim@gmail.com

# %%
df["Email"].apply(len)
# Out:
# 0    23
# 1    15
# 2    15
# 3    14
# 4    14
# Name: Email, dtype: int64

# %%
len(df['Email'])
# Out:
# 5

# %%
df.apply(len, axis = "rows")
# Out:
# First_Name    5
# Last_Name     5
# Email         5
# dtype: int64

# %%
df.apply(len, axis = 0)
# Out:
# First_Name    5
# Last_Name     5
# Email         5
# dtype: int64

# %%
df.apply(len, axis = 1) # 1 = columns
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# First_Name        Afifa Jahan
# Last_Name                Rafa
# Email         afifa@gmail.com
# dtype: object

# %%
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  asifantajrobin@gmal.com
# 1  Afrin Jahan      Rupa          afrin@cmail.com
# 2  Afifa Jahan      Rafa          afifa@gmail.com
# 3   Asif Antaj    Rayhan           asif@gmail.com
# 4      Md Azim     Uddin           azim@gmail.com

# %%
df.apply(lambda x: x.min())
# Out:
# First_Name        Afifa Jahan
# Last_Name                Rafa
# Email         afifa@gmail.com
# dtype: object

# %%
df.applymap(len)
# Out:
# C:\Users\Asif Antaj Robin\AppData\Local\Temp\ipykernel_8800\1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    First_Name  Last_Name  Email
# 0          10          5     23
# 1          11          4     15
# 2          11          4     15
# 3          10          6     14
# 4           7          5     14

# %%
df.applymap(str.lower)
# Out:
# C:\Users\Asif Antaj Robin\AppData\Local\Temp\ipykernel_8800\357608748.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(str.lower)
#     First_Name Last_Name                    Email
# 0   asif antaj     robin  asifantajrobin@gmal.com
# 1  afrin jahan      rupa          afrin@cmail.com
# 2  afifa jahan      rafa          afifa@gmail.com
# 3   asif antaj    rayhan           asif@gmail.com
# 4      md azim     uddin           azim@gmail.com

# %%
df
# Out:
#     First_Name Last_Name                    Email
# 0   Asif Antaj     Robin  asifantajrobin@gmal.com
# 1  Afrin Jahan      Rupa          afrin@cmail.com
# 2  Afifa Jahan      Rafa          afifa@gmail.com
# 3   Asif Antaj    Rayhan           asif@gmail.com
# 4      Md Azim     Uddin           azim@gmail.com

# %%
df['Email'].replace({"afrin@cmail.com":"afrinjahanrupa@Gmail.com", "azim@gmail.com":"azimuddin@gmail.com"}, inplace = True)
df
# Out:
# C:\Users\Asif Antaj Robin\AppData\Local\Temp\ipykernel_8800\3735581357.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Email'].replace({"afrin@cmail.com":"afrinjahanrupa@Gmail.com", "azim@gmail.com":"azimuddin@gmail.com"}, inplace = True)
#     First_Name Last_Name                     Email
# 0   Asif Antaj     Robin   asifantajrobin@gmal.com
# 1  Afrin Jahan      Rupa  afrinjahanrupa@Gmail.com
# 2  Afifa Jahan      Rafa           afifa@gmail.com
# 3   Asif Antaj    Rayhan            asif@gmail.com
# 4      Md Azim     Uddin       azimuddin@gmail.com

# %%
df = pd.read_csv("employee_data.csv")
df.head()
# Out:
#    EmployeeID             Name  Age  Gender   Department    JobTitle  Salary  \
# 0        1000  George Williams   50    Male           HR  Consultant   65057
# 1        1001       Jane Brown   36  Female        Sales   Executive   31239
# 2        1002   George Johnson   29  Female      Support     Manager   95661
# 3        1003  Hannah Williams   42   Other  Engineering     Manager   75272
# 4        1004     George Davis   40   Other           IT   Developer  119393
#
#   DateOfJoining MaritalStatus    Education  ...  \
# 0     10/8/2017        Single       Master  ...
# 1      3/7/2021        Single          PhD  ...
# 2     9/27/2016        Single  High School  ...
# 3    11/18/2018        Single          PhD  ...
# 4     3/14/2019       Married       Master  ...
#
#                            Email  PhoneNumber      City EmploymentType  \
# 0  george.williams@corporate.org   1762717327     Dhaka       Contract
# 1       jane.brown@corporate.org   1566784995    Sylhet      Part-time
# 2   george.johnson@corporate.org   1348371389  Rajshahi      Full-time
# 3  hannah.williams@corporate.org   1564436727   Barisal      Full-time
# 4       george.davis@example.com   1130130576     Dhaka      Part-time
#
#   IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled Certifications  \
# 0       No        16:21.8                   18               1            AWS
# 1       No        54:32.7                   10               5   Scrum Master
# 2      Yes        54:32.7                   17               9            AWS
# 3       No        16:21.8                    3               3   Data Analyst
# 4      Yes        27:16.4                   15               4   Scrum Master
#
#   PromotionEligible
# 0               Yes
# 1               Yes
# 2               Yes
# 3               Yes
# 4                No
#
# [5 rows x 25 columns]

# %%
df.rename(columns = {"Salary":"SalaryBDT"}, inplace = True)
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Age', 'Gender', 'Department', 'JobTitle',
#        'SalaryBDT', 'DateOfJoining', 'MaritalStatus', 'Education', 'OverTime',
#        'MonthlyIncome', 'Hobbies', 'ProgrammingSkills', 'Religion', 'Email',
#        'PhoneNumber', 'City', 'EmploymentType', 'IsRemote', 'LastWorkingDay',
#        'LeavesTakenLastYear', 'ProjectsHandled', 'Certifications',
#        'PromotionEligible'],
#       dtype='object')

# %%
df["IsRemote"]
# Out:
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
#       ...
# 545    Yes
# 546    Yes
# 547    Yes
# 548    Yes
# 549     No
# Name: IsRemote, Length: 550, dtype: object

# %%
df["IsRemote"].value_counts()
# Out:
# IsRemote
# No     291
# Yes    259
# Name: count, dtype: int64

# %%
df["IsRemote"].map({"Yes":True, "No":False})
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 545     True
# 546     True
# 547     True
# 548     True
# 549    False
# Name: IsRemote, Length: 550, dtype: bool

# %%
df
# Out:
#      EmployeeID             Name  Age  Gender   Department    JobTitle  \
# 0          1000  George Williams   50    Male           HR  Consultant
# 1          1001       Jane Brown   36  Female        Sales   Executive
# 2          1002   George Johnson   29  Female      Support     Manager
# 3          1003  Hannah Williams   42   Other  Engineering     Manager
# 4          1004     George Davis   40   Other           IT   Developer
# ..          ...              ...  ...     ...          ...         ...
# 545        1545        Bob Jones   39    Male  Engineering  Technician
# 546        1546    Jane Williams   35   Other    Logistics   Developer
# 547        1547     Diana Wilson   36  Female  Engineering     Analyst
# 548        1548    Hannah Taylor   52    Male           IT   Developer
# 549        1549     Fiona Miller   22    Male        Sales  Consultant
#
#      SalaryBDT DateOfJoining MaritalStatus    Education  ...  \
# 0        65057     10/8/2017        Single       Master  ...
# 1        31239      3/7/2021        Single          PhD  ...
# 2        95661     9/27/2016        Single  High School  ...
# 3        75272    11/18/2018        Single          PhD  ...
# 4       119393     3/14/2019       Married       Master  ...
# ..         ...           ...           ...          ...  ...
# 545      68714      7/3/2014        Single     Bachelor  ...
# 546      84093      9/1/2017      Divorced          PhD  ...
# 547      85419      8/3/2023      Divorced       Master  ...
# 548      79145     5/22/2010       Married       Master  ...
# 549     107425    12/26/2013       Married     Bachelor  ...
#
#                              Email  PhoneNumber        City EmploymentType  \
# 0    george.williams@corporate.org   1762717327       Dhaka       Contract
# 1         jane.brown@corporate.org   1566784995      Sylhet      Part-time
# 2     george.johnson@corporate.org   1348371389    Rajshahi      Full-time
# 3    hannah.williams@corporate.org   1564436727     Barisal      Full-time
# 4         george.davis@example.com   1130130576       Dhaka      Part-time
# ..                             ...          ...         ...            ...
# 545          bob.jones@example.com   1508844502    Rajshahi      Full-time
# 546    jane.williams@corporate.org   1947982501      Khulna      Part-time
# 547       diana.wilson@example.com   1361782146      Sylhet       Contract
# 548      hannah.taylor@company.com   1318980404  Chittagong       Contract
# 549       fiona.miller@example.com   1781051213      Sylhet      Full-time
#
#     IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled  \
# 0         No        16:21.8                   18               1
# 1         No        54:32.7                   10               5
# 2        Yes        54:32.7                   17               9
# 3         No        16:21.8                    3               3
# 4        Yes        27:16.4                   15               4
# ..       ...            ...                  ...             ...
# 545      Yes        54:32.7                   11               1
# 546      Yes        38:10.9                   25               4
# 547      Yes        32:43.6                   26               0
# 548      Yes        10:54.5                   16               8
# 549       No        00:00.0                    0               3
#
#     Certifications PromotionEligible
# 0              AWS               Yes
# 1     Scrum Master               Yes
# 2              AWS               Yes
# 3     Data Analyst               Yes
# 4     Scrum Master                No
# ..             ...               ...
# 545            AWS                No
# 546            PMP               Yes
# 547           CCNA                No
# 548            AWS               Yes
# 549            AWS               Yes
#
# [550 rows x 25 columns]

# %%
df["IsRemote"].replace({"Yes":True, "No":False})
# Out:
# C:\Users\Asif Antaj Robin\AppData\Local\Temp\ipykernel_8800\1603590291.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["IsRemote"].replace({"Yes":True, "No":False})
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 545     True
# 546     True
# 547     True
# 548     True
# 549    False
# Name: IsRemote, Length: 550, dtype: bool

# %%
df
# Out:
#      EmployeeID             Name  Age  Gender   Department    JobTitle  \
# 0          1000  George Williams   50    Male           HR  Consultant
# 1          1001       Jane Brown   36  Female        Sales   Executive
# 2          1002   George Johnson   29  Female      Support     Manager
# 3          1003  Hannah Williams   42   Other  Engineering     Manager
# 4          1004     George Davis   40   Other           IT   Developer
# ..          ...              ...  ...     ...          ...         ...
# 545        1545        Bob Jones   39    Male  Engineering  Technician
# 546        1546    Jane Williams   35   Other    Logistics   Developer
# 547        1547     Diana Wilson   36  Female  Engineering     Analyst
# 548        1548    Hannah Taylor   52    Male           IT   Developer
# 549        1549     Fiona Miller   22    Male        Sales  Consultant
#
#      SalaryBDT DateOfJoining MaritalStatus    Education  ...  \
# 0        65057     10/8/2017        Single       Master  ...
# 1        31239      3/7/2021        Single          PhD  ...
# 2        95661     9/27/2016        Single  High School  ...
# 3        75272    11/18/2018        Single          PhD  ...
# 4       119393     3/14/2019       Married       Master  ...
# ..         ...           ...           ...          ...  ...
# 545      68714      7/3/2014        Single     Bachelor  ...
# 546      84093      9/1/2017      Divorced          PhD  ...
# 547      85419      8/3/2023      Divorced       Master  ...
# 548      79145     5/22/2010       Married       Master  ...
# 549     107425    12/26/2013       Married     Bachelor  ...
#
#                              Email  PhoneNumber        City EmploymentType  \
# 0    george.williams@corporate.org   1762717327       Dhaka       Contract
# 1         jane.brown@corporate.org   1566784995      Sylhet      Part-time
# 2     george.johnson@corporate.org   1348371389    Rajshahi      Full-time
# 3    hannah.williams@corporate.org   1564436727     Barisal      Full-time
# 4         george.davis@example.com   1130130576       Dhaka      Part-time
# ..                             ...          ...         ...            ...
# 545          bob.jones@example.com   1508844502    Rajshahi      Full-time
# 546    jane.williams@corporate.org   1947982501      Khulna      Part-time
# 547       diana.wilson@example.com   1361782146      Sylhet       Contract
# 548      hannah.taylor@company.com   1318980404  Chittagong       Contract
# 549       fiona.miller@example.com   1781051213      Sylhet      Full-time
#
#     IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled  \
# 0         No        16:21.8                   18               1
# 1         No        54:32.7                   10               5
# 2        Yes        54:32.7                   17               9
# 3         No        16:21.8                    3               3
# 4        Yes        27:16.4                   15               4
# ..       ...            ...                  ...             ...
# 545      Yes        54:32.7                   11               1
# 546      Yes        38:10.9                   25               4
# 547      Yes        32:43.6                   26               0
# 548      Yes        10:54.5                   16               8
# 549       No        00:00.0                    0               3
#
#     Certifications PromotionEligible
# 0              AWS               Yes
# 1     Scrum Master               Yes
# 2              AWS               Yes
# 3     Data Analyst               Yes
# 4     Scrum Master                No
# ..             ...               ...
# 545            AWS                No
# 546            PMP               Yes
# 547           CCNA                No
# 548            AWS               Yes
# 549            AWS               Yes
#
# [550 rows x 25 columns]

# %%
df["IsRemote"] = df["IsRemote"].replace({"Yes":True, "No":False})
df.head()
# Out:
# C:\Users\Asif Antaj Robin\AppData\Local\Temp\ipykernel_8800\2055708019.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["IsRemote"] = df["IsRemote"].replace({"Yes":True, "No":False})
#    EmployeeID             Name  Age  Gender   Department    JobTitle  \
# 0        1000  George Williams   50    Male           HR  Consultant
# 1        1001       Jane Brown   36  Female        Sales   Executive
# 2        1002   George Johnson   29  Female      Support     Manager
# 3        1003  Hannah Williams   42   Other  Engineering     Manager
# 4        1004     George Davis   40   Other           IT   Developer
#
#    SalaryBDT DateOfJoining MaritalStatus    Education  ...  \
# 0      65057     10/8/2017        Single       Master  ...
# 1      31239      3/7/2021        Single          PhD  ...
# 2      95661     9/27/2016        Single  High School  ...
# 3      75272    11/18/2018        Single          PhD  ...
# 4     119393     3/14/2019       Married       Master  ...
#
#                            Email  PhoneNumber      City EmploymentType  \
# 0  george.williams@corporate.org   1762717327     Dhaka       Contract
# 1       jane.brown@corporate.org   1566784995    Sylhet      Part-time
# 2   george.johnson@corporate.org   1348371389  Rajshahi      Full-time
# 3  hannah.williams@corporate.org   1564436727   Barisal      Full-time
# 4       george.davis@example.com   1130130576     Dhaka      Part-time
#
#   IsRemote LastWorkingDay  LeavesTakenLastYear ProjectsHandled Certifications  \
# 0    False        16:21.8                   18               1            AWS
# 1    False        54:32.7                   10               5   Scrum Master
# 2     True        54:32.7                   17               9            AWS
# 3    False        16:21.8                    3               3   Data Analyst
# 4     True        27:16.4                   15               4   Scrum Master
#
#    PromotionEligible
# 0                Yes
# 1                Yes
# 2                Yes
# 3                Yes
# 4                 No
#
# [5 rows x 25 columns]

# %%
df["IsRemote"].value_counts()
# Out:
# IsRemote
# False    291
# True     259
# Name: count, dtype: int64

# %% [raw]
# Asif Antaj Robin
# Cumilla Polytechnic Institute (CPI)
# Computer Science and Technology (CST)
# Phone Number : 01312531960
