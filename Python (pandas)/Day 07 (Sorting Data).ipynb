# %% [markdown]
# # Sorting Data

# %%
import pandas as pd

# %%
People = {
    "First Name" : ["Asif_Antaj", "Afrin_Jahan", "Afifa_Jahan", "Asif_Antaj"],
    "Last Name" : ["Robin", "Rupa", "Rafa", "Rayhan"],
    "Email" : ["asifantajrobin@gmal.com", "afrin@gmail.com", "afifa@gmail.com", "asif@gmail.com"]
}

# %%
df = pd.DataFrame(People)
df
# Out:
#     First Name Last Name                    Email
# 0   Asif_Antaj     Robin  asifantajrobin@gmal.com
# 1  Afrin_Jahan      Rupa          afrin@gmail.com
# 2  Afifa_Jahan      Rafa          afifa@gmail.com
# 3   Asif_Antaj    Rayhan           asif@gmail.com

# %%
df.sort_values(by = "First Name")
# Out:
#     First Name Last Name                    Email
# 2  Afifa_Jahan      Rafa          afifa@gmail.com
# 1  Afrin_Jahan      Rupa          afrin@gmail.com
# 0   Asif_Antaj     Robin  asifantajrobin@gmal.com
# 3   Asif_Antaj    Rayhan           asif@gmail.com

# %%
df.sort_values(by = "First Name", ascending = False)
# Out:
#     First Name Last Name                    Email
# 0   Asif_Antaj     Robin  asifantajrobin@gmal.com
# 3   Asif_Antaj    Rayhan           asif@gmail.com
# 1  Afrin_Jahan      Rupa          afrin@gmail.com
# 2  Afifa_Jahan      Rafa          afifa@gmail.com

# %%
df.sort_values(by = ["First Name", "Last Name"], ascending = [False, True])
# Out:
#     First Name Last Name                    Email
# 3   Asif_Antaj    Rayhan           asif@gmail.com
# 0   Asif_Antaj     Robin  asifantajrobin@gmal.com
# 1  Afrin_Jahan      Rupa          afrin@gmail.com
# 2  Afifa_Jahan      Rafa          afifa@gmail.com

# %%
df
# Out:
#     First Name Last Name                    Email
# 0   Asif_Antaj     Robin  asifantajrobin@gmal.com
# 1  Afrin_Jahan      Rupa          afrin@gmail.com
# 2  Afifa_Jahan      Rafa          afifa@gmail.com
# 3   Asif_Antaj    Rayhan           asif@gmail.com

# %%
df.sort_index
# Out:
# <bound method DataFrame.sort_index of     First Name Last Name                    Email
# 0   Asif_Antaj     Robin  asifantajrobin@gmal.com
# 1  Afrin_Jahan      Rupa          afrin@gmail.com
# 2  Afifa_Jahan      Rafa          afifa@gmail.com
# 3   Asif_Antaj    Rayhan           asif@gmail.com>

# %%
df["Last Name"].sort_values()
# Out:
# 2      Rafa
# 3    Rayhan
# 0     Robin
# 1      Rupa
# Name: Last Name, dtype: object

# %%
df = pd.read_csv("employee_data.csv")
df.head()
# Out:
#    EmployeeID             Name  Age  Gender   Department    JobTitle  Salary  \
# 0        1000  George Williams   50    Male           HR  Consultant   65057
# 1        1001       Jane Brown   36  Female        Sales   Executive   31239
# 2        1002   George Johnson   29  Female      Support     Manager   95661
# 3        1003  Hannah Williams   42   Other  Engineering     Manager   75272
# 4        1004     George Davis   40   Other           IT   Developer  119393
#
#   DateOfJoining MaritalStatus    Education  ...  \
# 0     10/8/2017        Single       Master  ...
# 1      3/7/2021        Single          PhD  ...
# 2     9/27/2016        Single  High School  ...
# 3    11/18/2018        Single          PhD  ...
# 4     3/14/2019       Married       Master  ...
#
#                            Email  PhoneNumber      City EmploymentType  \
# 0  george.williams@corporate.org   1762717327     Dhaka       Contract
# ...

# %%
pd.set_option("display.max_columns", 20)
pd.set_option("display.max_rows", 500)

# %%
df.head()
# Out:
#    EmployeeID             Name  Age  Gender   Department    JobTitle  Salary  \
# 0        1000  George Williams   50    Male           HR  Consultant   65057
# 1        1001       Jane Brown   36  Female        Sales   Executive   31239
# 2        1002   George Johnson   29  Female      Support     Manager   95661
# 3        1003  Hannah Williams   42   Other  Engineering     Manager   75272
# 4        1004     George Davis   40   Other           IT   Developer  119393
#
#   DateOfJoining MaritalStatus    Education  ...  \
# 0     10/8/2017        Single       Master  ...
# 1      3/7/2021        Single          PhD  ...
# 2     9/27/2016        Single  High School  ...
# 3    11/18/2018        Single          PhD  ...
# 4     3/14/2019       Married       Master  ...
#
#                            Email  PhoneNumber      City EmploymentType  \
# 0  george.williams@corporate.org   1762717327     Dhaka       Contract
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Age', 'Gender', 'Department', 'JobTitle',
#        'Salary', 'DateOfJoining', 'MaritalStatus', 'Education', 'OverTime',
#        'MonthlyIncome', 'Hobbies', 'ProgrammingSkills', 'Religion', 'Email',
#        'PhoneNumber', 'City', 'EmploymentType', 'IsRemote', 'LastWorkingDay',
#        'LeavesTakenLastYear', 'ProjectsHandled', 'Certifications',
#        'PromotionEligible'],
#       dtype='object')

# %%
df.sort_values(by = "City", inplace = True)
df.head(10)
# Out:
#      EmployeeID            Name  Age  Gender Department    JobTitle  Salary  \
# 462        1462  Charlie Wilson   34   Other         IT  Technician  119097
# 79         1079     John Taylor   32  Female    Support   Executive   61324
# 440        1440   Hannah Wilson   58  Female      Sales     Manager   55121
# 250        1250      Bob Wilson   28   Other    Finance  Technician   30661
# 441        1441    George Jones   30  Female         IT    Engineer   67487
# 330        1330    Alice Wilson   27  Female  Logistics     Manager  104520
# 160        1160  Charlie Wilson   23   Other  Marketing     Analyst  106666
# 73         1073    Jane Johnson   28   Other         HR  Consultant   33726
# 161        1161      John Smith   49   Other    Finance   Executive  118204
# 336        1336    George Brown   25   Other    Support   Developer   61552
#
#     DateOfJoining MaritalStatus    Education  ...  \
# 462     2/17/2013      Divorced     Bachelor  ...
# ...

# %%
df["City"].head(20)
# Out:
# 462    Barisal
# 79     Barisal
# 440    Barisal
# 250    Barisal
# 441    Barisal
# 330    Barisal
# 160    Barisal
# 73     Barisal
# 161    Barisal
# 336    Barisal
# 70     Barisal
# 69     Barisal
# 68     Barisal
# 247    Barisal
# 340    Barisal
# 443    Barisal
# 60     Barisal
# 121    Barisal
# 170    Barisal
# 400    Barisal
# Name: City, dtype: object

# %%
df["Salary"]
# Out:
# 462    119097
# 79      61324
# 440     55121
# 250     30661
# 441     67487
#         ...
# 234    100587
# 236     98011
# 445     44056
# 439     40749
# 549    107425
# Name: Salary, Length: 550, dtype: int64

# %%
df["Salary"].nlargest(10)  #df.nlargest(10, "Salary")
# Out:
# 438    119881
# 416    119818
# 486    119570
# 540    119489
# 4      119393
# 74     119152
# 353    119099
# 462    119097
# 148    119022
# 181    118920
# Name: Salary, dtype: int64

# %%
df.nlargest(10, "Salary")  #df["Salary"].nlargest(10)
# Out:
#      EmployeeID             Name  Age  Gender Department    JobTitle  Salary  \
# 438        1438        Bob Jones   57    Male         IT  Consultant  119881
# 416        1416     Hannah Brown   50   Other    Finance     Manager  119818
# 486        1486     Alice Garcia   56    Male      Sales    Engineer  119570
# 540        1540        Bob Jones   58   Other    Finance    Engineer  119489
# 4          1004     George Davis   40   Other         IT   Developer  119393
# 74         1074      Ethan Brown   30    Male    Support    Engineer  119152
# 353        1353     Diana Garcia   33    Male  Logistics   Developer  119099
# 462        1462   Charlie Wilson   34   Other         IT  Technician  119097
# 148        1148     Bob Williams   54    Male  Marketing   Developer  119022
# 181        1181  George Williams   43  Female    Finance  Technician  118920
#
#     DateOfJoining MaritalStatus    Education  ...  \
# 438     9/22/2020        Single       Master  ...
# ...

# %%
df.nsmallest(10, "Salary")
# Out:
#      EmployeeID             Name  Age  Gender   Department    JobTitle  \
# 430        1430    Alice Johnson   55    Male    Logistics    Engineer
# 259        1259      Diana Jones   59   Other  Engineering    Engineer
# 250        1250       Bob Wilson   28   Other      Finance  Technician
# 429        1429       Jane Davis   47   Other      Finance    Engineer
# 94         1094   Hannah Johnson   45  Female      Support   Developer
# 1          1001       Jane Brown   36  Female        Sales   Executive
# 71         1071    Ethan Johnson   22    Male      Finance   Developer
# 18         1018      Ethan Davis   42   Other    Marketing   Developer
# 455        1455      Jane Wilson   46    Male    Marketing  Consultant
# 459        1459  Hannah Williams   41  Female           HR   Developer
#
#      Salary DateOfJoining MaritalStatus    Education  ...  \
# 430   30163     1/23/2020      Divorced          PhD  ...
# 259   30207     7/20/2023      Divorced  High School  ...
# ...

# %%
df["Salary"].nsmallest(10)
# Out:
# 430    30163
# 259    30207
# 250    30661
# 429    30671
# 94     31177
# 1      31239
# 71     31367
# 18     31969
# 455    33191
# 459    33631
# Name: Salary, dtype: int64

# %% [raw]
# Asif Antaj Robin
# Cumilla Polytechnic Institute (CPI)
# Computer Science and Technology (CST)
# Phone Number : 01312531960
